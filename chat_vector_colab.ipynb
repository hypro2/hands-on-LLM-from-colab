# %% [markdown]
# <a href="https://colab.research.google.com/github/hypro2/LLM-Multimodal-Colab/blob/main/chat_vector_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers sentencepiece accelerate protobuf

# %%
from transformers import AutoTokenizer


eng_tokenizer = AutoTokenizer.from_pretrained(
    "mistralai/Mistral-7B-v0.1"
)

kor_tokenizer = AutoTokenizer.from_pretrained(
    "maywell/Mistral-ko-7B-v0.1"
)

print(f"Mistral-7B: {eng_tokenizer.vocab_size}")  # -> 32000
print(f"Mistral-ko: {kor_tokenizer.vocab_size}")  # -> 42800
# Out:
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.50M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/630 [00:00<?, ?B/s]
# Mistral-7B: 32000
# Mistral-ko: 46080

# %%
from transformers import AutoModelForCausalLM
import torch

base_model = AutoModelForCausalLM.from_pretrained(
    "mistralai/Mistral-7B-v0.1",
    torch_dtype=torch.bfloat16,
    device_map="cpu",
)
inst_model = AutoModelForCausalLM.from_pretrained(
    "mistralai/Mistral-7B-Instruct-v0.1",
    torch_dtype=torch.bfloat16,
    device_map="cpu",
)
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %%
from transformers import AutoModelForCausalLM
import torch

cp_model = AutoModelForCausalLM.from_pretrained(
    "maywell/Mistral-ko-7B-v0.1",
    torch_dtype=torch.bfloat16,
    device_map="cuda",
)
# Out:
# config.json:   0%|          | 0.00/940 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# ...
# model-00001-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.75G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/755M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %%
for k, v in base_model.state_dict().items():
    print(k, v.shape)
# Out:
# model.embed_tokens.weight torch.Size([32000, 4096])
# model.layers.0.self_attn.q_proj.weight torch.Size([4096, 4096])
# model.layers.0.self_attn.k_proj.weight torch.Size([1024, 4096])
# model.layers.0.self_attn.v_proj.weight torch.Size([1024, 4096])
# model.layers.0.self_attn.o_proj.weight torch.Size([4096, 4096])
# model.layers.0.mlp.gate_proj.weight torch.Size([14336, 4096])
# model.layers.0.mlp.up_proj.weight torch.Size([14336, 4096])
# model.layers.0.mlp.down_proj.weight torch.Size([4096, 14336])
# model.layers.0.input_layernorm.weight torch.Size([4096])
# model.layers.0.post_attention_layernorm.weight torch.Size([4096])
# model.layers.1.self_attn.q_proj.weight torch.Size([4096, 4096])
# model.layers.1.self_attn.k_proj.weight torch.Size([1024, 4096])
# model.layers.1.self_attn.v_proj.weight torch.Size([1024, 4096])
# model.layers.1.self_attn.o_proj.weight torch.Size([4096, 4096])
# model.layers.1.mlp.gate_proj.weight torch.Size([14336, 4096])
# ...

# %%
for k, v in cp_model.state_dict().items():
    print(k, v.shape)
# Out:
# model.embed_tokens.weight torch.Size([46081, 4096])
# model.layers.0.self_attn.q_proj.weight torch.Size([4096, 4096])
# model.layers.0.self_attn.k_proj.weight torch.Size([1024, 4096])
# model.layers.0.self_attn.v_proj.weight torch.Size([1024, 4096])
# model.layers.0.self_attn.o_proj.weight torch.Size([4096, 4096])
# model.layers.0.mlp.gate_proj.weight torch.Size([14336, 4096])
# model.layers.0.mlp.up_proj.weight torch.Size([14336, 4096])
# model.layers.0.mlp.down_proj.weight torch.Size([4096, 14336])
# model.layers.0.input_layernorm.weight torch.Size([4096])
# model.layers.0.post_attention_layernorm.weight torch.Size([4096])
# model.layers.1.self_attn.q_proj.weight torch.Size([4096, 4096])
# model.layers.1.self_attn.k_proj.weight torch.Size([1024, 4096])
# model.layers.1.self_attn.v_proj.weight torch.Size([1024, 4096])
# model.layers.1.self_attn.o_proj.weight torch.Size([4096, 4096])
# model.layers.1.mlp.gate_proj.weight torch.Size([14336, 4096])
# ...

# %%
skip_layers = ["model.embed_tokens.weight", "lm_head.weight"]

for k, v in cp_model.state_dict().items():

    if (k in skip_layers) or ("layernorm" in k):
        continue

    chat_vector = inst_model.state_dict()[k] - base_model.state_dict()[k]

    new_value = v + chat_vector.to(v.device)

    v.copy_(new_value)

# %%
# cp_model.save_pretrained("./chat_model")
# Out:
# ---------------------------------------------------------------------------
# SafetensorError                           Traceback (most recent call last)
# <ipython-input-7-41710c273284> in <cell line: 1>()
# ----> 1 cp_model.save_pretrained("./chat_model")
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, token, save_peft_format, **kwargs)
#    2582                 # At some point we will need to deal better with save_function (used for TPU and other distributed
#    2583                 # joyfulness), but for now this enough.
# -> 2584                 safe_save_file(shard, os.path.join(save_directory, shard_file), metadata={"format": "pt"})
#    2585             else:
#    2586                 save_function(shard, os.path.join(save_directory, shard_file))
#
# ...
