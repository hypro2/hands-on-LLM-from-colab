# %% [markdown]
# <a href="https://colab.research.google.com/github/hypro2/step-by-step-colab/blob/main/google_gemini_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.6/146.6 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.7/598.7 kB 16.7 MB/s eta 0:00:00

# %%
import pathlib
import textwrap
import google.generativeai as genai
from google.colab import userdata
from IPython.display import display
from IPython.display import Markdown
from google.colab import userdata

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))
model = genai.GenerativeModel('gemini-pro')

# %%
response = model.generate_content("가면라이더의 역사를 알려줘.")
to_markdown(response.text)
# Out:
# > 가면라이더는 1971년부터 현재까지 일본에서 방영되고 있는 토쿠사츠TV 시리즈입니다. 이 시리즈는 이시노모리 쇼타로가 원작한 가면라이더 시리즈를 기반으로 만들어졌으며, 일본에서 가장 인기 있는 TV 시리즈 중 하나입니다.
# >
# > 1. 1971년: 가면라이더 1호
# > 첫 번째 가면라이더 시리즈는 1971년 4월 3일에 방영되었습니다. 이 시리즈는 호죠 히로시가 주연을 맡았으며, 그는 가면라이더 1호라는 캐릭터를 연기했습니다. 가면라이더 1호는 악의 조직인 쇼커에 의해 개조된 인간이며, 그는 쇼커와 싸우며 정의를 구현합니다.
# >
# > 2. 1972년: 가면라이더 V3
# > 1972년 2월 14일에 방영된 가면라이더 V3는 가면라이더 시리즈의 두 번째 작품입니다. 이 시리즈는 미키 키요시가 주연을 맡았으며, 그는 가면라이더 V3라는 캐릭터를 연기했습니다. 가면라이더 V3는 가면라이더 1호의 동료이며, 그는 쇼커와 싸우며 정의를 구현합니다.
# >
# > 3. 1973년: 가면라이더 X
# > 1973년 4월 2일에 방영된 가면라이더 X는 가면라이더 시리즈의 세 번째 작품입니다. 이 시리즈는 카와고에 유지가 주연을 맡았으며, 그는 가면라이더 X라는 캐릭터를 연기했습니다. 가면라이더 X는 가면라이더 1호와 가면라이더 V3의 선배이며, 그는 쇼커와 싸우며 정의를 구현합니다.
# >
# > 4. 1974년: 가면라이더 아마존
# > 1974년 10월 19일에 방영된 가면라이더 아마존은 가면라이더 시리즈의 네 번째 작품입니다. 이 시리즈는 모토키 마사히로가 주연을 맡았으며, 그는 가면라이더 아마존이라는 캐릭터를 연기했습니다. 가면라이더 아마존은 가면라이더 1호, 가면라이더 V3, 가면라이더 X의 동료이며, 그는 쇼커와 싸우며 정의를 구현합니다.
# >
# > 5. 1975년: 가면라이더 스트롱거
# ...

# %%
import PIL.Image

img = PIL.Image.open("/content/다운로드.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %%
model = genai.GenerativeModel('gemini-pro-vision')
response = model.generate_content([
    "이미지 속 인물이 되서, 사람들에게 한마디 해줘.",
    img
], stream=True)

# %%
response.resolve()

# %%
response.text
# Out:
# ' "변신!"'
